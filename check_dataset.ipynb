# %%
import phishing

# %%
task = phishing.Phishing(42)
task_docs = task.test_df
doc = task_docs.iloc[2]
context = task.fewshot_context(doc, 32, 0)
print(context)
# Out:
# You are a security officer.
# Classify the following SMS as 'Ham', 'Spam', 'Smishing'
#
# Text: Ron say fri leh. N he said ding tai feng cant make reservations. But he said wait lor.
#  URL: No
#  Email: No
#  Phone: No
#  Answer: ham
#
# Text: Collect your VALENTINE'S weekend to PARIS inc Flight & Hotel + £200 Prize guaranteed! Text: PARIS to No: 69101. www.rtf.sphosting.com
#  URL: yes
#  Email: No
#  Phone: yes
#  Answer: smishing
#
# Text: I am not having her number sir
#  URL: No
#  Email: No
#  Phone: No
#  Answer: ham
#
# Text: Cool. I am  &lt;#&gt;  inches long. hope you like them big!
#  URL: No
#  Email: No
#  Phone: No
#  Answer: ham
#
# Text: K, wat s tht incident?
#  URL: No
#  Email: No
#  Phone: No
#  Answer: ham
#
# Text: The wine is flowing and i'm i have nevering..
#  URL: No
#  Email: No
#  Phone: No
#  Answer: ham
#
# Text: I will vote for wherever my heart guides me
#  URL: No
#  Email: No
#  Phone: No
#  Answer: ham
#
# ...

# %%
train_df = task.train_df.sample(5, weights="LABEL_ID")
train_df
# Out:
#          LABEL                                               TEXT  URL EMAIL  \
# 355       spam  INTERFLORA - It's not too late to order Inter...   No    No
# 2688  smishing  URGENT! We are trying to contact U. Todays dra...   No    No
# 2326      spam  25p 4 alfie Moon's Children in need song on ur...   No    No
# 4158      spam  Your credits have been topped up for http://ww...  yes    No
# 3002  smishing  Congratulations YOU'VE Won. You're a Winner in...   No    No
#
#      PHONE  LABEL_ID
# 355    yes         2
# 2688   yes         1
# 2326   yes         2
# 4158    No         2
# 3002   yes         1

# %%
train_df
# Out:
#          LABEL                                               TEXT  URL EMAIL  \
# 2346  smishing  URGENT. Important information for 02 user. Tod...  yes    No
# 1590      spam       PRIVATE! Your 2003 Account Statement for 078   No    No
# 1375  smishing  Dear Sir Your Bank card has been blocked becau...   No    No
# 1431  smishing  \tYOU HAVE WON! As a valued Vodafone customer ...   No    No
# 1279  smishing  Dear customer your PAY2TMKYC has been expired,...   No    No
#
#      PHONE  LABEL_ID
# 2346    No         1
# 1590    No         2
# 1375   yes         1
# 1431   yes         1
# 1279   yes         1

# %%
from dataset import SMSDataset
import pandas as pd

# %%
train_df = pd.read_csv("data/sms_phishing_data_with_label.csv")
df = SMSDataset(train_df)

# %%
df.encode_sample()
# Out:
# good

# %%
df.__len__()
# Out:
# 5971
